# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('height_weight.csv')
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
## divide our dataset into independent and depenedent features
X=df[['Weight']]## independent feature
y=df['Height'] ## dependent feature
print(X)
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72

# %%
## train split test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X.shape
# Out:
# (23, 1)

# %%
X_test.shape, X_train.shape
# Out:
# ((5, 1), (18, 1))

# %%
# standardize the dataset Train independent data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
print(X_train)
print(X_test)
# Out:
# [[ 1.73689094]
#  [-0.92026952]
#  [ 1.4542143 ]
#  [ 0.21043706]
#  [-1.48562281]
#  [ 1.17153765]
#  [-1.6552288 ]
#  [-0.80719886]
#  [-0.24184557]
#  [ 0.0973664 ]
#  [-1.37255215]
#  [-1.03334018]
#  [-0.12877492]
#  [ 0.88886101]
#  [ 0.43657837]
#  [ 0.60618436]
#  [ 0.71925502]
#  [ 0.32350772]]

# %%
plt.scatter(X_train,y_train)

# %%
## train the model using LRM
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
coef=regressor.coef_
print("The coeffient is:",coef)
# Out:
# The coeffient is: [17.03440872]

# %%
interupt=regressor.intercept_
print("The Interupt is:",interupt)
# Out:
# The Interupt is: 157.5

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regressor.predict(X_train),'r')

# %%
plt.plot(X_test)
